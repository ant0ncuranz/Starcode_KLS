# %% [markdown]
# # **Zeichnen mit der Python-Turtle** 🐢

# %% [markdown]
# *Turtle* ist ein Modul in Python, mit dem man zeichnen kann.
# Mit verschiedenen Befehlen kann man die Schildkröte bewegen, die dann immer eine Spur hinterlässt.
# Um das *Turtle*-Modul zu nutzen, müssen wir es zuerst installieren. <br><br>Führe einmal folgenden Abschnitt aus ▶ <br><br>Dies kann ein wenig dauern. Irgendwann müsstest du eine Schildkröte sehen. Das ist die Python-Schildkröte!

# %%
# !pip3 install ColabTurtlePlus         # hier installieren wir das Turtle-Paket
from ColabTurtlePlus.Turtle import *  # hier importieren wir das Turtle-Paket
initializeTurtle()                    # hier initialisieren wir das Zeichenbrett
shape("turtle")                       # dadurch wird die Schildkröte angezeigt
# Out:
# ...
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#
#
#
#         <g id="turtle" visibility="visible" transform="rotate(90,400.0,300.0) translate(400.0, 300.0)">
# ...

# %% [markdown]
# Mit `initializeTurtle()` wird die Schildkröte erschaffen. Deshalb muss dieser Befehl immer ganz oben stehen. Python ließt den Code genau wie wir: Von oben nach unten. <br><br> Die folgenden Befehle veranlassen, dass sich die Schildkröte um 100 Pixel nach vorne bewegt, sich dann um 60° dreht und dann noch einmal um 100 Pixel nach vorne bewegt.

# %%
initializeTurtle()
forward(100)
left(60)
forward(100)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
# ...

# %% [markdown]
# <font color='sky blue'>*__Aufgabe a)   Zeichne ein Quadrat so wie im folgenden Bild.__ <br> Tipp: Dafür benötigst du einen rechten Winkel (90°).*</font><br>

# %% [markdown]
# ![Screenshot_Quadrat.png](data:image/png;base64,...)

# %%
initializeTurtle()

# hier kommt dein Code hin!
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#
#
#
#         <g id="turtle" visibility="visible" transform="rotate(90,400.0,300.0) translate(400.0, 300.0)">
# ...

# %% [markdown]
# <font color='sky blue'>*__Aufgabe b) Zeichne ein Rechteck, ähnlich zu diesem.__*</font>

# %% [markdown]
# ![Screenshot_Rechteck.png](data:image/png;base64,...)

# %%
initializeTurtle()

# hier kommt dein Code hin!

# %% [markdown]
# <font color='sky blue'>*__Aufgabe c) Zeichne ein Dreick, bei dem alle Seiten die Gleiche Länge haben.__

# %%
initializeTurtle()

# hier kommt dein Code hin!

# %% [markdown]
# Jetzt kommt Farbe ins Spiel! Wir wollen die Spur der Turtle einfärben. Hierfür gibt es den Befehl `color("farbe")`, den du im Code vor die jeweilige Bewegung der Turtle setzt.
# Für `farbe` kannst du eine beliebige Farbe auswählen. Typische Beispiele sind natürlich `red` (rot), `green` (grün), `blue` (blau) und `yellow` (gelb), es gibt aber noch viele weitere!
#
# Alle möglichen Farben findest du hier: https://matplotlib.org/stable/gallery/color/named_colors.html
#
# Im folgenden Beispiel läuft die Turtle einen Kreis mit einem Radius von 100 Pixeln und hinterlässt dabei eine blaue Spur.

# %%
initializeTurtle()
color("blue")
circle(100)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path d="M 400.0 300.0 A 100 100 0 0 0 425.882 296.593" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:blue;stroke-width:1"/><path d="M 425.882 296.593 A 100 100 0 0 0 450.0 286.603" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:blue;stroke-width:1"/><path d="M 450.0 286.603 A 100 100 0 0 0 470.711 270.711" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:blue;stroke-width:1"/><path d="M 470.711 270.711 A 100 100 0 0 0 486.603 250.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:blue;stroke-width:1"/><path d="M 486.603 250.0 A 100 100 0 0 0 496.593 225.882" stroke-linecap="round"
# ...

# %% [markdown]
# <font color='sky blue'>__Aufgabe d) Zeichne ein Quadrat, Rechteck oder Dreick, bei dem jede Seiten eine andere Farbe hat.__
# <br>
# Tipp: Mit dem Befehl `pensize(5)` wird die Linie 5-mal breiter. </font>

# %%
initializeTurtle()

# hier kommt dein Code hin!

# %% [markdown]
# # **Arbeit sparen mit Variablen ⏭**
#
# Wenn du mit den Winkeln und Seitenlängen experimentierst, musst du jedes Mal an verschiedenen Stellen Code verändern. Das kann unpraktisch sein! Aber keine Sorge, hier kommen Variablen ins Spiel. Variablen sind wie spezielle Namen für Werte, die du später noch einmal verwenden möchtest. <br><br> Übrigens kannst du selbst entscheiden, wie die Variable heißen soll. Du könntest zum Beispiel einen 45° Winkel als `winkel` abspeichern oder deinen Namen als `name`. Von nun an existieren diese Variablen und du kannst sie einfach aufrufen.

# %% [markdown]
# <font color='sky blue'>*__Aufgabe a) Wiederhole das Erstellen von Variablen!__ Erstelle mindestens eine Zahl und einen String.*</font>

# %%
# hier kommt dein Code hin!

# %% [markdown]
# <font color='sky blue'> __Aufgabe b) Zeichne wie vorhin ein Quadrat, aber dieses Mal mithilfe von Variablen!__ Erstelle eine Variable `winkel` für den rechten Winkel und eine Variable `länge` für die Seitenlänge des Quadrats. Probiere verschiedene Seitenlängen aus! </font>

# %%
initializeTurtle()

# hier kommt dein Code hin!

# %% [markdown]
# # **Dinge wiederholen mit Schleifen 🎀**
#
# Stell dir vor, du möchtest viele Quadrate zeichnen oder denselben Text mehrmals ausgeben. Es wäre sehr anstrengend, wenn du den Code ganz oft hintereinander aufschreiben müsstest. Aber zum Glück gibt es eine Lösung: Schleifen! Mit Schleifen können wir Python sagen, dass wir eine Anweisung mehrmals ausführen möchten. <br><br>Schau dir einmal an was folgendes Programm macht.

# %%
for i in range(3):
  print("Hallo")
# Out:
# Hallo
# Hallo
# Hallo

# %% [markdown]
# Jetzt bist du dran!
#
# Das Quadrat aus einer der vorherigen Aufgaben erforderte viele Textzeilen. Vielleicht geht das auch schneller?
#
# <font color='sky blue'>*__Aufgabe a) Schreibe ein Programm, dass ein Quadrat zeichnet, nur diesmal mit möglichst wenigen Zeilen.__<br> Tipp: Verwende eine Schleife, die vier mal durchlaufen wird.*</font>

# %%
initializeTurtle()

# hier kommt dein Code hin!

# %% [markdown]
# <font color='sky blue'>*__Aufgabe b) Zeichne eine gestrichelte Linie, mit Hilfe einer Schleife.__<br>Tipp: Mit `penup()` zeichnet die Schildkröte beim Bewegen nicht mehr. Mit `pendown()` hinterlässt sie wieder eine Linie.*</font>

# %%
initializeTurtle()

# hier kommt dein Code hin!

# %% [markdown]
# <font color='sky blue'>*__Aufgabe c) Lass deine Striche der gestrichelten Linie immer länger werden.__<br>Tipp: Du kannst die Zahlen von der `range()`-Funktion benutzen.*</font>

# %%
initializeTurtle()

# hier kommt dein Code hin!

# %% [markdown]
# # **Selbst Befehle erfinden mit Funktionen 🪄**
#
# Vielleicht hast du dich schon gefragt, woher die Befehle wie `forward()`, `print()` oder `penup()` eigentlich kommen. Die Antwort ist ganz einfach: Jemand hat sie erfunden!<br> Diese Befehle, die wir auch Funktionen nennen, sind Anweisungen, die der Computer versteht und ausführt. Und das Beste ist, dass wir solche Funktionen ganz einfach selbst erfinden können!
#
# In Python kannst du eine Funktion mit dem Wort `def` definieren. Führe einmal den nächsten Codeabschnitt aus.

# %%
def linie_hin_und_her():
  forward(150)
  backward(150)

# %% [markdown]
# <font color='sky blue'>*__Aufgabe a) Rufe die Funktion `linie_hin_und_her` ein paar mal hinterander auf und ändere zwischendurch die Laufrichtung der Schildkröte.__*</font>

# %%
initializeTurtle()

# hier kommt dein Code hin!

# %% [markdown]
# Funktionen können auch innerhalb von anderen Funktionen verwendet werden. Folgende Funktion zeichnet einen Stern.

# %%
initializeTurtle()

def stern():
  for i in range(5):
    linie_hin_und_her()
    left(360/5)

stern()

# %% [markdown]
# Übrigens: Eine Runde sind 360°. Da der Stern 5 Zacken hat und die Abstände zwischen den Zacken gleich sein sollen, wurde für den Winkel 360° geteilt durch 5 gerechnet. Python ist nämlich wie ein Taschenrechner! Beispielsweise kannst du folgende Rechenoperationen verwenden:
# - `+` (plus)
# - `-` (minus)
# - `*` (mal)
# - `/` (geteilt)

# %%
print("2 plus 3 ist", 2 + 3)
print("6 minus 2 ist", 6 - 2)
print("3 mal 7 ist", 2 * 7)
print("64 geteilt durch 4 ist", 64 / 4)

# %% [markdown]
# <font color='sky blue'>*__Aufgabe b) Schreibe eine Funktion, die ein Quadrat zeichnet und führe die Funktion anschließend aus.__<br> Tipp: Du kannst deinen Code aus einer vorherigen Aufgabe verwenden.*</font>

# %%
initializeTurtle()

# hier kommt dein Code hin!

# %% [markdown]
# <font color='sky blue'>*__Aufgabe c) Male eine Blume wie in der Abbildung! Schreibe dafür eine Funktion, die deine Quadrat-Funktion aufruft.__<br> Tipp: Schau dir nochmal die `stern`-Funktion an. Statt Striche zu zeichnen, möchtest du nun Quadrate zeichnen. Ansonsten ändert sich gar nicht so viel!
# <br> Noch ein Tipp: Durch den Befehl `speed(10)` wird die Schildkröte schneller.*</font>

# %% [markdown]
# ![Screenshot_Blume.png](data:image/png;base64,...)

# %%
initializeTurtle()

# hier kommt dein Code hin!
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
# ...

# %% [markdown]
# # **Noch flexibler: Funktionen mit Parametern 🦑**

# %% [markdown]
# Für unsere Zeichnungen können Parameter nützlich sein, wenn wir unterschiedlich große Figuren zeichnen wollen. Die folgende Funktion zeichnet ein Quadrat, bei dem wir die Seitenlänge `x` festlegen können.

# %%
def quadrat(x):
  initializeTurtle()
  for i in range(4):
    forward(x)
    left(90)

# %% [markdown]
# Die `quadrat`-Funktion zeichnet also nicht immer ein Quadrat mit der gleichen Größe, sondern möchte diesmal gesagt bekommen, mit welcher Größe sie das Quadrat zeichnen soll.
#
# <font color='sky blue'>*__Aufgabe a) Führe die Funktion `quadrat` aus. Teste was passiert, wenn du unterschiedliche Zahlen übergibst.__*</font>

# %%
initializeTurtle()

# hier kommt dein Code hin!

# %% [markdown]
# <font color='sky blue'>*__Aufgabe b) Schreibe eine Funktion `figur`, die ein Form zeichnet. Die Funktion soll die Seitenlänge und Anzahl an Ecken übergeben bekommen.__<br> Tipp: Schau dir nochmal die `quadrat`-Funktion an. <br>Noch ein Tipp: Ähnlich zur Blumen-Aufgabe, berechnest du den Winkel mit `360 / kanten`.*</font>

# %%
initializeTurtle()

def figur(länge, kanten):

# hier kommt dein Code hin!

# %% [markdown]
# <font color='sky blue'>*__Aufgabe c) Erstelle eine Figur deiner Wahl, z.B. ein Mandala! Hierzu kannst du verschiedene Figuren verwenden und dich z.B. an deinem Code zur Blumen-Aufgabe orientieren.__<br> Tipp: Du kannst verschiedene Formen (z.B. Quadrate, Rechtecke, Kreise) benutzten. Manche Formen haben wir schon als Funktionen erstellt. Außerdem kannst du mit verschiedenen Farben und Strichdicken experimentieren. Lass deiner Kreativität freien Lauf!*</font>

# %%
initializeTurtle()

# Beispiel

shape("blank") # hierdurch wird die Schildkröte nicht angezeigt
speed(10)

def mandala():

  color("darkred")
  for i in range(4):
    circle(100)
    left(360/20)
  color("steelblue")
  for i in range(4):
    circle(100)
    left(360/20)
  color("goldenrod")
  for i in range(4):
    circle(100)
    left(360/20)
  color("teal")
  for i in range(4):
    circle(100)
    left(360/20)
  color("limegreen")
  for i in range(4):
    circle(100)
    left(360/20)


  color("purple")
  pensize(2)
  penup()
  forward(220)
  left(90)
  pendown()
  circle(220)
  penup()
  color("grey")
  left(90)
  backward(10)
  right(90)
  pendown()
  circle(230)

mandala()
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path d="M 400.0 300.0 A 100 100 0 0 0 400.0 100.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:darkred;stroke-width:1"/><path d="M 400.0 100.0 A 100 100 0 0 0 400.0 300.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:darkred;stroke-width:1"/><path d="M 400.0 300.0 A 100 100 0 0 0 338.197 109.789" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:darkred;stroke-width:1"/><path d="M 338.197 109.789 A 100 100 0 0 0 400.0 300.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:darkred;stroke-width:1"/><path d="M 400.0 300.0 A 100 100 0 0 0 282.443 138.197" stroke-linecap="round"
# ...

# %% [markdown]
# # **Mit Python reden 💬**
#
# Verwende die inputs, die wir vorhin behandelt haben, um Variablen zu definieren und deine Zeichnungen zu verändern.

# %%
name = input("Wie heißt du?")
print("Hallo", name,"!")

# %% [markdown]
# <font color='sky blue'>__Aufgabe a) Nun bist du dran: Male ein Quadrat und definiere die Seitenlänge mit `input()`!__<br>

# %%
initializeTurtle()

# hier kommt dein Code hin!

# %% [markdown]
# # **Bedingungen stellen mit Verzweigungen 🌱**
#
# Manchmal muss der Computer Entscheidungen treffen, genau wie wir. Nun geht es darum, wie du dem Computer beibringst, verschiedene Wege zu wählen und je nach Situation unterschiedlich zu entscheiden. Das nennt man Verzweigungen!
#
# Führe den folgenden Code abschnitt aus.

# %%
def bewegung():
  richtung = input("links oder rechts?")

  if richtung == "links":
    left(45)

  if richtung == "rechts":
    right(45)

  forward(100)

# %% [markdown]
# <font color='sky blue'>*__Aufgabe a) Rufe die Funktion `bewegung()` mehrmals hintereinander auf.__*</font>

# %%
initializeTurtle()

# hier kommt dein Code hin!
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#
#
#
#
#       </svg>

# %% [markdown]
# <font color='sky blue'>*__Aufgabe b) Erstelle eine Funktion mit einer Bedingung, die je entweder einen roten oder blauen Strich zeichnet und rufe sie auf!__<br> Tipp: Du kannst den bereits geschriebenen Code aus einer vorherigen Aufgabe verwenden.*</font>

# %%
initializeTurtle()

# hier kommt dein Code hin!

# %% [markdown]
# Jetzt darfst du noch so viele Dinge ausprobieren, wie du möchtest!!

# %%
# Hier ist Platz für deinen Code, aber füge gerne noch weitere Code-Blöcke hinzu!
